# %%
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df = pd.read_csv(r"C:\Users\bezis\Downloads\Smart-Resume-Job-Matching-System\data\cleaned_job_descriptions.csv")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bezis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_text(text):

    text = text.lower()

    text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)

    words = text.split()

    words = [w for w in words if w not in stop_words]

    return " ".join(words)

# %%
df["cleaned_description"] = df["clean_job_text"].apply(clean_text)

# %%
df[["clean_job_text","cleaned_description"]].head(2
                                                  )
# Out:
#                                       clean_job_text  \
# 0  requirements c vbnet basics net framework net ...
# 1  requirements c net framework basics aspnet raz...
#
#                                  cleaned_description
# 0  requirements c vbnet basics net framework net ...
# 1  requirements c net framework basics aspnet raz...

# %%
skill_map = {
    "spring framework basics": "spring",
    "spring boot": "spring",
    "javascript": "js",
    "node js": "nodejs",
    "react js": "react",
    "machine learning": "ml",
    "deep learning": "dl"
}

# %%
def normalize_skills(text):

    for k,v in skill_map.items():

        text = text.replace(k,v)

    return text

# %%
df["cleaned_description"] = df["cleaned_description"].apply(normalize_skills)
